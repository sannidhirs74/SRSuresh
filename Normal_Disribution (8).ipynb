# %%
import pandas as pd
import numpy as np

# %%
beml_df = pd.read_csv("BEML.csv")
beml_df[0:5]

# %%
glaxo_df = pd.read_csv("GLAXO.csv")
glaxo_df.head()

# %%
beml_df = beml_df[['Date', 'Close']]
glaxo_df = glaxo_df[['Date', 'Close']]

# %%
beml_df

# %%
type(pd.DatetimeIndex(glaxo_df['Date']))

# %%
'''The DataFrames have a date column, so we can
create a DatetimeIndex index from this column Date. It will ensure that the rows are sorted by time in
ascending order.'''
glaxo_df = glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date']))
beml_df = beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))

# %%
beml_df.head()

# %%
glaxo_df

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
plt.plot(glaxo_df.Close);


plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
glaxo_df['gain'] = glaxo_df.Close.pct_change(periods = 1)
beml_df['gain'] = beml_df.Close.pct_change(periods = 1)

# %%
glaxo_df
# Out:
#                   Date    Close      gain
# Date
# 2010-01-04  2010-01-04  1625.65       NaN
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50 -0.001283
# 2016-12-27  2016-12-27  2701.75 -0.007986
# 2016-12-28  2016-12-28  2702.15  0.000148
# 2016-12-29  2016-12-29  2727.90  0.009529
# 2016-12-30  2016-12-30  2729.80  0.000697
#
# [1739 rows x 3 columns]

# %%
#drop first row since it is NaN
glaxo_df = glaxo_df.dropna()
beml_df = beml_df.dropna()

# %%
plt.figure(figsize = (15, 6));
plt.subplot(1,2,1)
plt.plot(glaxo_df.gain)
plt.title('Glaxo')

plt.subplot(1,2,2)
plt.plot(beml_df.gain)
plt.title('Beml')
# Out:
# Text(0.5, 1.0, 'Beml')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sn.distplot(glaxo_df.gain, label = 'Glaxo');
sn.distplot(beml_df.gain, label = 'BEML');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
plt.show()

# %%
print('Mean:', round(glaxo_df.gain.mean(), 4))
print('Standard Deviation: ', round(glaxo_df.gain.std(), 4))

# %%
print('Mean: ', round(beml_df.gain.mean(), 4))
print('Standard Deviation: ', round(beml_df.gain.std(), 4))

# %%
from scipy import stats
#Probability of making 2% loss or higher in Glaxo
stats.norm.cdf( -0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())

# %%
#Probability of making 2% gain or higher in Glaxo
from scipy import stats
1 - stats.norm.cdf(0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())

# %% [markdown]
# ### Inclass Exercise

# %% [markdown]
# ### Compute 2% loss or gain for BEML

# %% [markdown]
# #prob(X<70) using normal distribution where RV follows N(60,10)
#
# from scipy import stats
# stats.norm.cdf()
#
# from scipy.stats import norm
# norm.cdf()
#
#
# from scipy.stats.norm import cdf
# cdf()
#
# import scipy.stats.norm.cdf as cdf
#
# ```
# # This is formatted as code
# ```

# %%
glaxo_df.head()

# %%
beml_df.head()

# %%
glaxo_df.shape

# %%
#if X ~ N(60,10) then find P(X<70)
'''from scipy import stats
or
import scipy.stats as stats'''
from scipy import stats

stats.norm.cdf(x=70,loc=60,scale=10)

# %%
#P(X>70)
1-stats.norm.cdf(x=70,loc=60,scale=10)

# %%
stats.norm.cdf(x=680,loc=711,scale=29)

# %%
stats.norm.cdf(680,711,29)

# %%
#Gmat score data, find P(697<x<740) for mean 711 and sd 29

stats.norm.cdf(740,711,29) - stats.norm.cdf(697,711,29)

# %%
import numpy as np

# %%
np.random.randint(1,1000,100)

# %%
import random

# %%
random.randint(10,100)

# %%
np.random.uniform(0,1,100)

# %%
np.random.binomial(1,0.99,100)

# %%
#generation of 50 normal random numbers with mean 25, Sd 5
np.random.normal(25,5,50)

# %%
import numpy as np

2500/np.sqrt(140)

# %%
from scipy import stats
stats.norm.interval(0.95,loc=1990,scale=(2500/np.sqrt(140)))      #confidence level, point estimator, popn standard deviation(sigma/sqrt(n))

# %%
from scipy import stats
stats.norm.interval(0.9,loc=1990,scale=(2500/np.sqrt(140)))

# %%
###construct 95% confidence interval for mean card balance using t distn

stats.t.interval(0.95,139,1990,(2833/np.sqrt(140)))

# %%
# to find the normal/critical values of t and z we use ppf

# %%
stats.norm.ppf(1-(0.05/2))

# %%
stats.t.ppf((1-(0.05/2)),139)    #point prob function or percent prob function

# %%
import pandas as pd
beml_df=pd.read_csv("BEML.csv")
beml_df.head()

# %%
beml_df=beml_df.iloc[:,[0,5]]

# %%
glaxo_df=pd.read_csv("GLAXO.csv")
glaxo_df.head()

# %%
glaxo_df=glaxo_df.iloc[:,[0,5]]

# %%
beml_df["gain"]=beml_df.Close.pct_change(periods=1)
beml_df.head()

# %%
glaxo_df["gain"]=glaxo_df.Close.pct_change(periods=1)
glaxo_df.head()

# %%
beml_df=beml_df.dropna()
glax_df=glaxo_df.dropna()

# %%
len(beml_df)

# %%
#from scipy import stats
#import scipy.stats as stats
#stats.norm.cdf()

#from scipy.stats import norm
#import scipy.stats.norm as norm
#norm.cdf()

# %%
#To find P(X<70) given X~N(60,10)
from scipy import stats

stats.norm.cdf(x=70,loc=60,scale=10)

# %%
#P(X>70)
1-stats.norm.cdf(x=70,loc=60,scale=10)

# %%
stats.norm.cdf(x=680,loc=711,scale=29)

# %%
stats.norm.cdf(x=740,loc=711,scale=29)-stats.norm.cdf(x=697,loc=711,scale=29)

# %%
from scipy.stats import binom
binom.pmf(2,2,0.5)  #tossing of a coin twice and finding the probability of having 2 heads

# %%
import numpy as np
#gen discrete uniform
np.random.randint(1,100,1000)  #start,end,num_samples

# %%
#continuous uniform(Rectangular)
np.random.uniform(0,1,100) #low,high,size

# %%
#binomial random numbers
np.random.binomial(1,0.58,50) #(success_representation,prob(success),num_samples)

# %%
np.random.normal(10,78,25)  #(mean,std,num_samples)

# %%
import pandas as pd
import numpy as np
pd.DataFrame({
    "Uniform":np.random.uniform(10,50,10),
    "Binomial":np.random.binomial(5,0.5,10),
    "Normal":np.random.normal(25,7,10)
})

# %%
glaxo_df.shape

# %%
import scipy.stats as stats
stats.t.interval(0.95,1737,loc=glaxo_df.gain.mean(),scale=glaxo_df.gain.std()/np.sqrt(1738))

# %%
import scipy.stats

or from scipy import stats

# %%
#from scipy import stats.norm.cdf as cdf
#cdf(x,loc=(mean),scale=(std))

# %%
from scipy import stats
stats.norm.cdf(70,loc=60,scale=10)

# %%
from scipy import stats
import numpy as np

# %%
stats.norm.interval(0.95,1990,2500/np.sqrt(140))      #confidence level(1-alpha),sample mean,standard deviation(sigma/sqrt(n))

# %%
stats.norm.interval(0.90,1990,2500/np.sqrt(140))

# %%
stats.norm.interval(0.99,1990,2500/np.sqrt(140))

# %%
stats.norm.ppf(0.975)

# %%
#to find out z at 90% confidence level
stats.norm.ppf(1-(0.10/2))

# %%
#to find out z at 99% confidence level
stats.norm.ppf(1-(0.01/2))

# %%
#finding confidence levels using t distribution

stats.t.interval(0.95,139,1990,2833/np.sqrt(140))   #confidence level,degree of freedom(n-1),sample mean, sample sd/sqrt(n)

# %%
stats.t.ppf((1-0.05/2),139)

# %%
#Construct 95% confidence interval to the rate of return(gain) of glaxo and Beml
n=glaxo_df.shape[0]
mean=glaxo_df.gain.mean()
std=glaxo_df.gain.std()
stats.t.interval(0.95,n-1,mean,std/np.sqrt(n))

# %%
stats.norm.interval(0.95,mean,std/np.sqrt(n))

# %%
n=beml_df.shape[0]
mean=beml_df.gain.mean()
std=beml_df.gain.std()
stats.t.interval(0.95,n-1,mean,std/np.sqrt(n))

# %%
stats.norm.interval(0.95,mean,std/np.sqrt(n))

# %%
from scipy import stats

# %%
stats.binom.pmf(2,2,0.5)      #(x(loc), n(num of trials), p(prob of success))

# %%
stats.binom.pmf(6,10,0.5)

# %%
stats.binom.cdf(1,2,0.5)

# %%
1-stats.binom.cdf(1,2,0.5)

# %%
import numpy as np

# %%
#random number gen-Uniform
a=np.random.randint(6)
a

# %%
np.random.randint(1,6,size=10)

# %%
#random number gen-Binomial
np.random.binomial(1,0.65,10)     #success representation(1 or 0),P(success),size(number of random values)

# %%
#P(X<70), given that X ~ N(mu=60,sigma=10)

import scipy.stats as st
st.norm.cdf(x=70,loc=60,scale=10)

# %%
#P(X<=680) ,  X ~ N(mu=711,sigma=29)
import scipy.stats as st
st.norm.cdf(x=680,loc=711,scale=29)

# %%
import scipy.stats as st
st.norm.cdf(x=740,loc=711,scale=29)-st.norm.cdf(x=697,loc=711,scale=29)
